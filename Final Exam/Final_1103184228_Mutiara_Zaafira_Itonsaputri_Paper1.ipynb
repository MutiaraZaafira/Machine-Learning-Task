# %% [markdown]
# <a href="https://colab.research.google.com/github/MutiaraZaafira/Machine-Learning-Task/blob/main/Final%20Exam/Final_1103184228_Mutiara_Zaafira_Itonsaputri_Paper1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **EMA**

# %%
class EMA:
    def __init__(self, model, decay):
        self.decay = decay
        self.shadow = {}
        self.original = {}

        for name, param in model.named_parameters():
            if param.requires_grad:
                self.shadow[name] = param.data.clone()

    def __call__(self, model, num_updates):
        decay = min(self.decay, (1.0 + num_updates) / (10.0 + num_updates))
        for name, param in model.named_parameters():
            if param.requires_grad:
                assert name in self.shadow
                new_average = (1.0 - decay) * param.data + decay * self.shadow[name]
                self.shadow[name] = new_average.clone()

    def assign(self, model):
        for name, param in model.named_parameters():
            if param.requires_grad:
                assert name in self.shadow
                self.original[name] = param.data.clone()
                param.data = self.shadow[name]

    def resume(self, model):
        for name, param in model.named_parameters():
            if param.requires_grad:
                assert name in self.shadow
                param.data = self.original[name]

# %% [markdown]
# **TRANSFORMS**

# %%
import random
import torchvision.transforms.functional as R

class RandomRotation(object):
    def __init__(self, degrees, seed=1):
        self.degrees = (-degrees, degrees)
        random.seed(seed)
    
    @staticmethod
    def get_params(degrees):
        angle = random.uniform(degrees[0], degrees[1])
        return angle

    def __call__(self, img):
        angle = self.get_params(self.degrees)
        return R.rotate(img, angle, False, False, None, None)

# %% [markdown]
# **DATASET**

# %%
import torch
import numpy as np
from PIL import Image
from torchvision import transforms

class MnistDataset(torch.utils.data.Dataset):
    def __init__(self, training=True, transform=None):
        if training==True:
            f = open('/content/drive/MyDrive/MnistSimpleCNN-master/data/MNIST/raw/train-images-idx3-ubyte', 'rb')
            xs = np.array(np.frombuffer(f.read(), np.uint8, offset=16))
            f.close()
            f = open('/content/drive/MyDrive/MnistSimpleCNN-master/data/MNIST/raw/train-labels-idx1-ubyte', 'rb')
            ys = np.array(np.frombuffer(f.read(), np.uint8, offset=8))
            f.close()
        else:
            f = open('/content/drive/MyDrive/MnistSimpleCNN-master/data/MNIST/raw/t10k-images-idx3-ubyte', 'rb')
            xs = np.array(np.frombuffer(f.read(), np.uint8, offset=16))
            f.close()
            f = open('/content/drive/MyDrive/MnistSimpleCNN-master/data/MNIST/raw/t10k-labels-idx1-ubyte', 'rb')
            ys = np.array(np.frombuffer(f.read(), np.uint8, offset=8))
            f.close()
        xs = np.reshape(xs, (-1, 28, 28, 1)).astype(np.float32)
        ys = ys.astype(np.int)
        self.x_data = xs
        self.y_data = ys
        self.transform = transform

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = Image.fromarray(self.x_data[idx].reshape(28, 28))
        y = torch.tensor(np.array(self.y_data[idx]))
        if self.transform:
            x = self.transform(x)
        x = transforms.ToTensor()(np.array(x)/255)
        return x, y

# %% [markdown]
# **Model M3**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ModelM3(nn.Module):
    def __init__(self):
        super(ModelM3, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, bias=False)       # output becomes 26x26
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 48, 3, bias=False)      # output becomes 24x24
        self.conv2_bn = nn.BatchNorm2d(48)
        self.conv3 = nn.Conv2d(48, 64, 3, bias=False)      # output becomes 22x22
        self.conv3_bn = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 80, 3, bias=False)      # output becomes 20x20
        self.conv4_bn = nn.BatchNorm2d(80)
        self.conv5 = nn.Conv2d(80, 96, 3, bias=False)      # output becomes 18x18
        self.conv5_bn = nn.BatchNorm2d(96)
        self.conv6 = nn.Conv2d(96, 112, 3, bias=False)     # output becomes 16x16
        self.conv6_bn = nn.BatchNorm2d(112)
        self.conv7 = nn.Conv2d(112, 128, 3, bias=False)    # output becomes 14x14
        self.conv7_bn = nn.BatchNorm2d(128)
        self.conv8 = nn.Conv2d(128, 144, 3, bias=False)    # output becomes 12x12
        self.conv8_bn = nn.BatchNorm2d(144)
        self.conv9 = nn.Conv2d(144, 160, 3, bias=False)    # output becomes 10x10
        self.conv9_bn = nn.BatchNorm2d(160)
        self.conv10 = nn.Conv2d(160, 176, 3, bias=False)   # output becomes 8x8
        self.conv10_bn = nn.BatchNorm2d(176)
        self.fc1 = nn.Linear(11264, 10, bias=False)
        self.fc1_bn = nn.BatchNorm1d(10)
    def get_logits(self, x):
        x = (x - 0.5) * 2.0
        conv1 = F.relu(self.conv1_bn(self.conv1(x)))
        conv2 = F.relu(self.conv2_bn(self.conv2(conv1)))
        conv3 = F.relu(self.conv3_bn(self.conv3(conv2)))
        conv4 = F.relu(self.conv4_bn(self.conv4(conv3)))
        conv5 = F.relu(self.conv5_bn(self.conv5(conv4)))
        conv6 = F.relu(self.conv6_bn(self.conv6(conv5)))
        conv7 = F.relu(self.conv7_bn(self.conv7(conv6)))
        conv8 = F.relu(self.conv8_bn(self.conv8(conv7)))
        conv9 = F.relu(self.conv9_bn(self.conv9(conv8)))
        conv10 = F.relu(self.conv10_bn(self.conv10(conv9)))
        flat1 = torch.flatten(conv10.permute(0, 2, 3, 1), 1)
        logits = self.fc1_bn(self.fc1(flat1))
        return logits
    def forward(self, x):
        logits = self.get_logits(x)
        return F.log_softmax(logits, dim=1)

# %% [markdown]
# **Model 5**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ModelM5(nn.Module):
    def __init__(self):
        super(ModelM5, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5, bias=False)
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 5, bias=False)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 96, 5, bias=False)
        self.conv3_bn = nn.BatchNorm2d(96)
        self.conv4 = nn.Conv2d(96, 128, 5, bias=False)
        self.conv4_bn = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 160, 5, bias=False)
        self.conv5_bn = nn.BatchNorm2d(160)
        self.fc1 = nn.Linear(10240, 10, bias=False)
        self.fc1_bn = nn.BatchNorm1d(10)
    def get_logits(self, x):
        x = (x - 0.5) * 2.0
        conv1 = F.relu(self.conv1_bn(self.conv1(x)))
        conv2 = F.relu(self.conv2_bn(self.conv2(conv1)))
        conv3 = F.relu(self.conv3_bn(self.conv3(conv2)))
        conv4 = F.relu(self.conv4_bn(self.conv4(conv3)))
        conv5 = F.relu(self.conv5_bn(self.conv5(conv4)))
        flat5 = torch.flatten(conv5.permute(0, 2, 3, 1), 1)
        logits = self.fc1_bn(self.fc1(flat5))
        return logits
    def forward(self, x):
        logits = self.get_logits(x)
        return F.log_softmax(logits, dim=1)

# %% [markdown]
# **Model 7**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ModelM7(nn.Module):
    def __init__(self):
        super(ModelM7, self).__init__()
        self.conv1 = nn.Conv2d(1, 48, 7, bias=False)    # output becomes 22x22
        self.conv1_bn = nn.BatchNorm2d(48)
        self.conv2 = nn.Conv2d(48, 96, 7, bias=False)   # output becomes 16x16
        self.conv2_bn = nn.BatchNorm2d(96)
        self.conv3 = nn.Conv2d(96, 144, 7, bias=False)  # output becomes 10x10
        self.conv3_bn = nn.BatchNorm2d(144)
        self.conv4 = nn.Conv2d(144, 192, 7, bias=False) # output becomes 4x4
        self.conv4_bn = nn.BatchNorm2d(192)
        self.fc1 = nn.Linear(3072, 10, bias=False)
        self.fc1_bn = nn.BatchNorm1d(10)
    def get_logits(self, x):
        x = (x - 0.5) * 2.0
        conv1 = F.relu(self.conv1_bn(self.conv1(x)))
        conv2 = F.relu(self.conv2_bn(self.conv2(conv1)))
        conv3 = F.relu(self.conv3_bn(self.conv3(conv2)))
        conv4 = F.relu(self.conv4_bn(self.conv4(conv3)))
        flat1 = torch.flatten(conv4.permute(0, 2, 3, 1), 1)
        logits = self.fc1_bn(self.fc1(flat1))
        return logits
    def forward(self, x):
        logits = self.get_logits(x)
        return F.log_softmax(logits, dim=1)

# %% [markdown]
# **TRAIN**

# %%
#imports -------------------------------------------------------------------------#
import sys
import os
import argparse
import numpy as np 
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torchsummary import summary
from PIL import Image

def run(p_seed=0, p_epochs=150, p_kernel_size=5, p_logdir="temp"):
     # random number generator seed ------------------------------------------------#
     SEED = p_seed
     torch.backends.cudnn.deterministic = True
     torch.backends.cudnn.benchmark = False
     torch.manual_seed(SEED)
     torch.cuda.manual_seed_all(SEED)
     np.random.seed(SEED)

     # kernel size of model --------------------------------------------------------#
     KERNEL_SIZE = p_kernel_size

#     # number of epochs ------------------------------------------------------------#
     NUM_EPOCHS = p_epochs

#     # file names ------------------------------------------------------------------#
     if not os.path.exists("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s"%p_logdir):
         os.makedirs("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s"%p_logdir)
     OUTPUT_FILE = str("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s/log%03d.out"%(p_logdir,SEED))
     MODEL_FILE = str("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s/model%03d.pth"%(p_logdir,SEED))

#     # enable GPU usage ------------------------------------------------------------#
     use_cuda = torch.cuda.is_available()
     device = torch.device("cuda" if use_cuda else "cpu")
     if use_cuda == False:
         print("WARNING: CPU will be used for training.")
         exit(0)

     # data augmentation methods ---------------------------------------------------#
     transform = transforms.Compose([
         RandomRotation(20, seed=SEED),
         transforms.RandomAffine(0, translate=(0.2, 0.2)),
         ])

#     # data loader -----------------------------------------------------------------#
     train_dataset = MnistDataset(training=True, transform=transform)
     test_dataset = MnistDataset(training=False, transform=None)
     train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=120, shuffle=True)
     test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False)

     # model selection -------------------------------------------------------------#
     if(KERNEL_SIZE == 3):
         model = ModelM3().to(device)
     elif(KERNEL_SIZE == 5):
         model = ModelM5().to(device)
     elif(KERNEL_SIZE == 7):
         model = ModelM7().to(device)

     summary(model, (1, 28, 28))

     # hyperparameter selection ----------------------------------------------------#
     ema = EMA(model, decay=0.999)
     optimizer = optim.Adam(model.parameters(), lr=0.001)
     lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98)

     # delete result file ----------------------------------------------------------#
     f = open(OUTPUT_FILE, 'w')
     f.close()

     # global variables ------------------------------------------------------------#
     g_step = 0
     max_correct = 0

     # training and evaluation loop ------------------------------------------------#
     for epoch in range(NUM_EPOCHS):
         #--------------------------------------------------------------------------#
         # train process                                                            #
         #--------------------------------------------------------------------------#
         model.train()
         train_loss = 0
         train_corr = 0
         for batch_idx, (data, target) in enumerate(train_loader):
             data, target = data.to(device), target.to(device)
             optimizer.zero_grad()
             output = model(data)
             loss = F.nll_loss(output, target)
             train_pred = output.argmax(dim=1, keepdim=True)
             train_corr += train_pred.eq(target.view_as(train_pred)).sum().item()
             train_loss += F.nll_loss(output, target, reduction='sum').item()
             loss.backward()
             optimizer.step()
             g_step += 1
             ema(model, g_step)
             if batch_idx % 100 == 0:
                 print('Train Epoch: {} [{:05d}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                     epoch, batch_idx * len(data), len(train_loader.dataset),
                     100. * batch_idx / len(train_loader), loss.item()))
         train_loss /= len(train_loader.dataset)
         train_accuracy = 100 * train_corr / len(train_loader.dataset)
         #--------------------------------------------------------------------------#
         # test process                                                             #
         #--------------------------------------------------------------------------#
         model.eval()
         ema.assign(model)
         test_loss = 0
         correct = 0
         total_pred = np.zeros(0)
         total_target = np.zeros(0)
         with torch.no_grad():
             for data, target in test_loader:
                 data, target = data.to(device), target.to(device)
                 output = model(data)
                 test_loss += F.nll_loss(output, target, reduction='sum').item()
                 pred = output.argmax(dim=1, keepdim=True)
                 total_pred = np.append(total_pred, pred.cpu().numpy())
                 total_target = np.append(total_target, target.cpu().numpy())
                 correct += pred.eq(target.view_as(pred)).sum().item()
             if(max_correct < correct):
                 torch.save(model.state_dict(), MODEL_FILE)
                 max_correct = correct
                 print("Best accuracy! correct images: %5d"%correct)
         ema.resume(model)

         #--------------------------------------------------------------------------#
         # output                                                                   #
         #--------------------------------------------------------------------------#
         test_loss /= len(test_loader.dataset)
         test_accuracy = 100 * correct / len(test_loader.dataset)
         best_test_accuracy = 100 * max_correct / len(test_loader.dataset)
         print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%) (best: {:.2f}%)\n'.format(
             test_loss, correct, len(test_loader.dataset), test_accuracy, best_test_accuracy))

         f = open(OUTPUT_FILE, 'a')
         f.write(" %3d %12.6f %9.3f %12.6f %9.3f %9.3f\n"%(epoch, train_loss, train_accuracy, test_loss, test_accuracy, best_test_accuracy))
         f.close()

         #--------------------------------------------------------------------------#
         # update learning rate scheduler                                           #
         #--------------------------------------------------------------------------#
         lr_scheduler.step()

p_seed = int(input ("Seeds: ")) #parameter yang digunakan untuk mempengaruhi randomisasi.
p_epoch = int(input ("Epoch: ")) #banyaknya epoch
p_trials = int(input ("Trials: ")) #banyaknya percobaan yang dilakukan
p_kernel_size = int (input ("Kernel size: ")) #3 untuk M3; 5 untuk M5; 7 untuk M7
p_gpu = int(input ("GPU: ")) #index gpu yang digunakan ; karena GPU hanya 1 maka indexnya 0
p_logdir = input ("Logdir: ") #folder untuk menyimpan hasil training

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]=str(p_gpu)

for x in range (p_trials):
   run(p_seed + x, p_epoch, p_kernel_size, p_logdir)
# Out:
# Seeds: 0
# Epoch: 15
# Trials: 20
# Kernel size: 3
# GPU: 0
# Logdir: modelM3_baru
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.657581
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:992: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.644509
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.431458
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.324747
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.259744
# Best accuracy! correct images:  9837
#
# Test set: Average loss: 0.1619, Accuracy: 9837/10000 (98.37%) (best: 98.37%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.235940
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.210491
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.228506
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.151298
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.167080
# Best accuracy! correct images:  9886
#
# Test set: Average loss: 0.0985, Accuracy: 9886/10000 (98.86%) (best: 98.86%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.127794
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.150670
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.130251
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.082413
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.131678
#
# Test set: Average loss: 0.1041, Accuracy: 9837/10000 (98.37%) (best: 98.86%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.106520
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.102702
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.096546
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.137737
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.134460
# Best accuracy! correct images:  9891
#
# Test set: Average loss: 0.0515, Accuracy: 9891/10000 (98.91%) (best: 98.91%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.089080
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.039457
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.159233
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.078115
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.101541
# Best accuracy! correct images:  9903
#
# Test set: Average loss: 0.0593, Accuracy: 9903/10000 (99.03%) (best: 99.03%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.036826
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.155474
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.067597
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.095855
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.062005
# Best accuracy! correct images:  9919
#
# Test set: Average loss: 0.0450, Accuracy: 9919/10000 (99.19%) (best: 99.19%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.081563
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.062785
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.099966
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.053231
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.048340
#
# Test set: Average loss: 0.0535, Accuracy: 9916/10000 (99.16%) (best: 99.19%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.077022
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.036999
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.041235
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.098196
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.031108
#
# Test set: Average loss: 0.0514, Accuracy: 9886/10000 (98.86%) (best: 99.19%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.033450
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.033347
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.066571
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.104280
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.013436
# Best accuracy! correct images:  9933
#
# Test set: Average loss: 0.0316, Accuracy: 9933/10000 (99.33%) (best: 99.33%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.081663
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.027163
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.062122
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.053770
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.084259
# Best accuracy! correct images:  9950
#
# Test set: Average loss: 0.0227, Accuracy: 9950/10000 (99.50%) (best: 99.50%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.022905
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.023031
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.082158
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.050110
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.052766
#
# Test set: Average loss: 0.0495, Accuracy: 9894/10000 (98.94%) (best: 99.50%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.043772
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.050741
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.083352
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.021639
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.080005
#
# Test set: Average loss: 0.0344, Accuracy: 9919/10000 (99.19%) (best: 99.50%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.023516
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.017063
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.011853
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.065598
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.145552
#
# Test set: Average loss: 0.0260, Accuracy: 9936/10000 (99.36%) (best: 99.50%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.019121
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.008322
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.019055
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.038371
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.031357
#
# Test set: Average loss: 0.0321, Accuracy: 9920/10000 (99.20%) (best: 99.50%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.022707
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.011515
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.030962
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.083175
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.049369
#
# Test set: Average loss: 0.0220, Accuracy: 9949/10000 (99.49%) (best: 99.50%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.636028
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.647832
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.413704
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.371092
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.312717
# Best accuracy! correct images:  9855
#
# Test set: Average loss: 0.1321, Accuracy: 9855/10000 (98.55%) (best: 98.55%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.279296
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.204168
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.219688
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.138832
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.209977
# Best accuracy! correct images:  9894
#
# Test set: Average loss: 0.0764, Accuracy: 9894/10000 (98.94%) (best: 98.94%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.222111
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.198160
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.105505
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.105949
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.097200
#
# Test set: Average loss: 0.0640, Accuracy: 9882/10000 (98.82%) (best: 98.94%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.129771
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.120033
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.138586
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.095951
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.059565
#
# Test set: Average loss: 0.0637, Accuracy: 9893/10000 (98.93%) (best: 98.94%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.106627
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.104141
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.109954
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.082695
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.066076
# Best accuracy! correct images:  9935
#
# Test set: Average loss: 0.0500, Accuracy: 9935/10000 (99.35%) (best: 99.35%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.081759
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.062350
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.036390
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.068565
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.055213
#
# Test set: Average loss: 0.0434, Accuracy: 9911/10000 (99.11%) (best: 99.35%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.027435
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.067844
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.165016
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.100631
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.043272
#
# Test set: Average loss: 0.0366, Accuracy: 9924/10000 (99.24%) (best: 99.35%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.025664
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.027037
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.126853
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.061582
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.089322
# Best accuracy! correct images:  9939
#
# Test set: Average loss: 0.0279, Accuracy: 9939/10000 (99.39%) (best: 99.39%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.072304
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.047984
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.024025
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.020876
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.040103
#
# Test set: Average loss: 0.1174, Accuracy: 9770/10000 (97.70%) (best: 99.39%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.084903
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.046909
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.027359
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.021023
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.052601
#
# Test set: Average loss: 0.0378, Accuracy: 9917/10000 (99.17%) (best: 99.39%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.019038
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.037114
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.053252
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.076374
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.040991
# Best accuracy! correct images:  9952
#
# Test set: Average loss: 0.0238, Accuracy: 9952/10000 (99.52%) (best: 99.52%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.044495
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.023144
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.018346
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.020728
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.048959
#
# Test set: Average loss: 0.0326, Accuracy: 9918/10000 (99.18%) (best: 99.52%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.020996
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.028380
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.036434
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.066193
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.031297
#
# Test set: Average loss: 0.0259, Accuracy: 9940/10000 (99.40%) (best: 99.52%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.032968
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.008648
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.033553
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.048118
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.006949
#
# Test set: Average loss: 0.0236, Accuracy: 9941/10000 (99.41%) (best: 99.52%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.074636
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.053239
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.101880
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.046302
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.028826
#
# Test set: Average loss: 0.0212, Accuracy: 9944/10000 (99.44%) (best: 99.52%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.781280
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.692152
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.421331
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.367163
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.257468
# Best accuracy! correct images:  9903
#
# Test set: Average loss: 0.1202, Accuracy: 9903/10000 (99.03%) (best: 99.03%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.252424
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.193160
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.233927
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.214553
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.141100
#
# Test set: Average loss: 0.1153, Accuracy: 9847/10000 (98.47%) (best: 99.03%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.139321
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.246029
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.133498
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.132394
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.119488
# Best accuracy! correct images:  9916
#
# Test set: Average loss: 0.0648, Accuracy: 9916/10000 (99.16%) (best: 99.16%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.134954
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.118088
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.117211
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.131605
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.110608
#
# Test set: Average loss: 0.0752, Accuracy: 9908/10000 (99.08%) (best: 99.16%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.088950
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.119878
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.104338
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.062575
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.074147
#
# Test set: Average loss: 0.0526, Accuracy: 9896/10000 (98.96%) (best: 99.16%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.060501
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.099784
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.045697
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.078684
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.037615
# Best accuracy! correct images:  9931
#
# Test set: Average loss: 0.0401, Accuracy: 9931/10000 (99.31%) (best: 99.31%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.076354
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.038584
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.035968
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.064649
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.103038
#
# Test set: Average loss: 0.0537, Accuracy: 9902/10000 (99.02%) (best: 99.31%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.057977
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.033324
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.067285
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.023938
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.039615
# Best accuracy! correct images:  9942
#
# Test set: Average loss: 0.0267, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.086950
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.076146
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.053447
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.073173
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.018065
#
# Test set: Average loss: 0.0588, Accuracy: 9879/10000 (98.79%) (best: 99.42%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.094665
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.063347
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.026867
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.096968
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.067503
#
# Test set: Average loss: 0.0395, Accuracy: 9915/10000 (99.15%) (best: 99.42%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.061731
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.091165
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.045358
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.067471
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.015655
# Best accuracy! correct images:  9943
#
# Test set: Average loss: 0.0215, Accuracy: 9943/10000 (99.43%) (best: 99.43%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.080825
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.102098
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.036923
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.148351
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.092958
#
# Test set: Average loss: 0.0472, Accuracy: 9898/10000 (98.98%) (best: 99.43%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.085442
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.047829
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.035247
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.145235
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.025829
# Best accuracy! correct images:  9946
#
# Test set: Average loss: 0.0232, Accuracy: 9946/10000 (99.46%) (best: 99.46%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.046056
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.105847
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.126860
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.116408
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.038241
# Best accuracy! correct images:  9950
#
# Test set: Average loss: 0.0222, Accuracy: 9950/10000 (99.50%) (best: 99.50%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.117456
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.064354
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.012129
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.012989
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.083457
#
# Test set: Average loss: 0.0281, Accuracy: 9933/10000 (99.33%) (best: 99.50%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.845584
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.734352
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.437420
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.326101
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.247609
# Best accuracy! correct images:  9885
#
# Test set: Average loss: 0.1193, Accuracy: 9885/10000 (98.85%) (best: 98.85%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.216039
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.256882
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.280726
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.194597
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.140175
#
# Test set: Average loss: 0.1018, Accuracy: 9880/10000 (98.80%) (best: 98.85%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.186126
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.136455
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.108124
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.074210
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.144340
# Best accuracy! correct images:  9894
#
# Test set: Average loss: 0.0642, Accuracy: 9894/10000 (98.94%) (best: 98.94%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.071753
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.145950
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.105642
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.091366
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.082137
# Best accuracy! correct images:  9927
#
# Test set: Average loss: 0.0493, Accuracy: 9927/10000 (99.27%) (best: 99.27%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.062197
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.120297
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.080788
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.126620
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.091405
#
# Test set: Average loss: 0.0468, Accuracy: 9926/10000 (99.26%) (best: 99.27%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.043135
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.081558
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.052101
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.095565
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.090906
# Best accuracy! correct images:  9936
#
# Test set: Average loss: 0.0314, Accuracy: 9936/10000 (99.36%) (best: 99.36%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.060068
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.079037
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.090488
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.149981
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.064171
#
# Test set: Average loss: 0.0414, Accuracy: 9916/10000 (99.16%) (best: 99.36%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.163638
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.180105
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.018359
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.074644
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.038348
#
# Test set: Average loss: 0.0406, Accuracy: 9917/10000 (99.17%) (best: 99.36%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.040033
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.109288
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.046035
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.029140
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.055925
# Best accuracy! correct images:  9949
#
# Test set: Average loss: 0.0242, Accuracy: 9949/10000 (99.49%) (best: 99.49%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.123827
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.024680
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.032425
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.049376
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.024074
#
# Test set: Average loss: 0.0252, Accuracy: 9942/10000 (99.42%) (best: 99.49%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.027743
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.018247
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.032427
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.040801
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.144443
#
# Test set: Average loss: 0.0374, Accuracy: 9916/10000 (99.16%) (best: 99.49%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.047892
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.033654
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.075119
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.068551
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.068801
#
# Test set: Average loss: 0.0298, Accuracy: 9929/10000 (99.29%) (best: 99.49%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.028120
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.020230
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.031988
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.028503
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.018780
# Best accuracy! correct images:  9959
#
# Test set: Average loss: 0.0223, Accuracy: 9959/10000 (99.59%) (best: 99.59%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.043615
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.043500
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.036319
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.079436
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.105572
#
# Test set: Average loss: 0.0249, Accuracy: 9945/10000 (99.45%) (best: 99.59%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.067338
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.025339
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.077073
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.069595
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.039734
#
# Test set: Average loss: 0.0171, Accuracy: 9946/10000 (99.46%) (best: 99.59%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.558000
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.653399
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.420209
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.381024
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.298903
# Best accuracy! correct images:  9863
#
# Test set: Average loss: 0.1451, Accuracy: 9863/10000 (98.63%) (best: 98.63%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.319992
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.284144
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.230777
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.164753
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.167446
# Best accuracy! correct images:  9900
#
# Test set: Average loss: 0.0762, Accuracy: 9900/10000 (99.00%) (best: 99.00%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.149612
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.145609
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.162328
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.117442
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.118292
#
# Test set: Average loss: 0.0714, Accuracy: 9898/10000 (98.98%) (best: 99.00%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.149527
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.141583
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.095074
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.153903
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.078501
#
# Test set: Average loss: 0.0531, Accuracy: 9892/10000 (98.92%) (best: 99.00%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.119296
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.168053
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.069165
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.072366
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.123790
#
# Test set: Average loss: 0.1034, Accuracy: 9799/10000 (97.99%) (best: 99.00%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.102470
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.068896
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.070841
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.048174
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.059310
#
# Test set: Average loss: 0.0485, Accuracy: 9883/10000 (98.83%) (best: 99.00%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.062143
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.102418
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.094362
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.119238
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.042054
# Best accuracy! correct images:  9923
#
# Test set: Average loss: 0.0365, Accuracy: 9923/10000 (99.23%) (best: 99.23%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.105992
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.076473
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.053850
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.058642
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.050086
# Best accuracy! correct images:  9941
#
# Test set: Average loss: 0.0268, Accuracy: 9941/10000 (99.41%) (best: 99.41%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.093252
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.053234
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.091019
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.037479
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.063136
#
# Test set: Average loss: 0.0415, Accuracy: 9904/10000 (99.04%) (best: 99.41%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.064008
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.024237
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.057032
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.034912
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.062785
#
# Test set: Average loss: 0.0285, Accuracy: 9935/10000 (99.35%) (best: 99.41%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.063845
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.047825
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.038667
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.019925
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.053809
#
# Test set: Average loss: 0.0325, Accuracy: 9915/10000 (99.15%) (best: 99.41%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.014022
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.019782
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.045088
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.026275
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.078192
# Best accuracy! correct images:  9946
#
# Test set: Average loss: 0.0223, Accuracy: 9946/10000 (99.46%) (best: 99.46%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.069519
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.015590
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.053114
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.017965
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.066985
#
# Test set: Average loss: 0.0549, Accuracy: 9868/10000 (98.68%) (best: 99.46%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.018787
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.101096
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.022984
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.054154
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.039477
# Best accuracy! correct images:  9955
#
# Test set: Average loss: 0.0182, Accuracy: 9955/10000 (99.55%) (best: 99.55%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.052175
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.042892
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.040338
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.035010
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.014549
#
# Test set: Average loss: 0.0219, Accuracy: 9938/10000 (99.38%) (best: 99.55%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.686705
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.636909
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.500591
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.399536
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.265424
# Best accuracy! correct images:  9876
#
# Test set: Average loss: 0.1297, Accuracy: 9876/10000 (98.76%) (best: 98.76%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.291581
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.230881
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.211286
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.244806
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.189460
# Best accuracy! correct images:  9908
#
# Test set: Average loss: 0.0717, Accuracy: 9908/10000 (99.08%) (best: 99.08%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.156650
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.175611
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.153027
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.102010
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.172819
# Best accuracy! correct images:  9919
#
# Test set: Average loss: 0.0579, Accuracy: 9919/10000 (99.19%) (best: 99.19%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.082733
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.107878
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.137950
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.132370
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.134464
#
# Test set: Average loss: 0.0517, Accuracy: 9910/10000 (99.10%) (best: 99.19%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.068503
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.132361
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.151496
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.042199
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.086636
# Best accuracy! correct images:  9926
#
# Test set: Average loss: 0.0381, Accuracy: 9926/10000 (99.26%) (best: 99.26%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.076532
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.080748
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.112639
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.108302
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.097141
#
# Test set: Average loss: 0.0452, Accuracy: 9913/10000 (99.13%) (best: 99.26%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.123889
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.107375
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.117692
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.042292
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.054257
#
# Test set: Average loss: 0.0395, Accuracy: 9915/10000 (99.15%) (best: 99.26%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.038821
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.054192
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.105297
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.037437
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.018675
#
# Test set: Average loss: 0.0730, Accuracy: 9794/10000 (97.94%) (best: 99.26%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.163745
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.073082
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.036221
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.076724
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.069739
#
# Test set: Average loss: 0.0373, Accuracy: 9920/10000 (99.20%) (best: 99.26%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.085635
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.021672
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.055591
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.082918
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.036077
#
# Test set: Average loss: 0.0442, Accuracy: 9891/10000 (98.91%) (best: 99.26%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.022675
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.019059
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.080692
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.040866
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.053503
# Best accuracy! correct images:  9933
#
# Test set: Average loss: 0.0323, Accuracy: 9933/10000 (99.33%) (best: 99.33%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.063232
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.016361
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.045562
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.022225
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.017789
# Best accuracy! correct images:  9945
#
# Test set: Average loss: 0.0237, Accuracy: 9945/10000 (99.45%) (best: 99.45%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.008977
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.046959
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.131088
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.049676
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.048415
# Best accuracy! correct images:  9949
#
# Test set: Average loss: 0.0237, Accuracy: 9949/10000 (99.49%) (best: 99.49%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.101935
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.108104
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.114373
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.046113
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.062052
#
# Test set: Average loss: 0.0555, Accuracy: 9861/10000 (98.61%) (best: 99.49%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.024397
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.015200
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.014243
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.010641
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.030314
#
# Test set: Average loss: 0.0244, Accuracy: 9934/10000 (99.34%) (best: 99.49%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.687867
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.579472
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.444794
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.340334
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.255302
# Best accuracy! correct images:  9837
#
# Test set: Average loss: 0.1457, Accuracy: 9837/10000 (98.37%) (best: 98.37%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.203337
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.210760
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.236550
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.151624
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.123923
# Best accuracy! correct images:  9910
#
# Test set: Average loss: 0.0637, Accuracy: 9910/10000 (99.10%) (best: 99.10%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.157810
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.133131
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.144132
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.133007
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.166987
# Best accuracy! correct images:  9917
#
# Test set: Average loss: 0.0574, Accuracy: 9917/10000 (99.17%) (best: 99.17%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.114605
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.107641
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.106079
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.055837
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.176933
# Best accuracy! correct images:  9930
#
# Test set: Average loss: 0.0451, Accuracy: 9930/10000 (99.30%) (best: 99.30%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.175254
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.056164
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.161829
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.057681
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.058873
#
# Test set: Average loss: 0.0524, Accuracy: 9882/10000 (98.82%) (best: 99.30%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.074384
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.096577
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.096232
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.053072
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.091877
# Best accuracy! correct images:  9947
#
# Test set: Average loss: 0.0253, Accuracy: 9947/10000 (99.47%) (best: 99.47%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.059565
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.049555
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.040543
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.031681
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.078674
#
# Test set: Average loss: 0.0408, Accuracy: 9938/10000 (99.38%) (best: 99.47%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.066159
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.058700
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.049518
# ...
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.038065
#
# Test set: Average loss: 0.0438, Accuracy: 9889/10000 (98.89%) (best: 99.48%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.022663
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.018422
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.028790
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.032087
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.121714
#
# Test set: Average loss: 0.0303, Accuracy: 9933/10000 (99.33%) (best: 99.48%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.034611
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.063153
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.096753
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.095010
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.038061
#
# Test set: Average loss: 0.0268, Accuracy: 9941/10000 (99.41%) (best: 99.48%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.026963
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.025867
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.026021
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.068982
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.045933
#
# Test set: Average loss: 0.0647, Accuracy: 9820/10000 (98.20%) (best: 99.48%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.051479
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.065272
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.074931
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.127438
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.024996
#
# Test set: Average loss: 0.0303, Accuracy: 9921/10000 (99.21%) (best: 99.48%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.012807
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.073604
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.008113
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.019269
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.034829
#
# Test set: Average loss: 0.0555, Accuracy: 9836/10000 (98.36%) (best: 99.48%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.729480
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.616798
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.404357
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.324300
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.301039
# Best accuracy! correct images:  9881
#
# Test set: Average loss: 0.1322, Accuracy: 9881/10000 (98.81%) (best: 98.81%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.192276
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.181822
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.258460
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.177018
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.140035
#
# Test set: Average loss: 0.1056, Accuracy: 9880/10000 (98.80%) (best: 98.81%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.212858
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.165338
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.192354
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.103666
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.169558
# Best accuracy! correct images:  9899
#
# Test set: Average loss: 0.0690, Accuracy: 9899/10000 (98.99%) (best: 98.99%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.122248
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.160704
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.060761
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.091180
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.069058
# Best accuracy! correct images:  9937
#
# Test set: Average loss: 0.0360, Accuracy: 9937/10000 (99.37%) (best: 99.37%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.048609
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.129981
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.080696
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.088586
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.095348
# Best accuracy! correct images:  9942
#
# Test set: Average loss: 0.0313, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.056354
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.090232
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.089987
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.034754
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.040514
#
# Test set: Average loss: 0.0476, Accuracy: 9904/10000 (99.04%) (best: 99.42%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.049432
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.065664
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.053101
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.051216
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.025265
#
# Test set: Average loss: 0.0388, Accuracy: 9923/10000 (99.23%) (best: 99.42%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.033503
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.051364
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.043614
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.024963
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.041591
#
# Test set: Average loss: 0.0359, Accuracy: 9910/10000 (99.10%) (best: 99.42%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.087160
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.067585
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.067013
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.051357
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.032984
#
# Test set: Average loss: 0.0433, Accuracy: 9891/10000 (98.91%) (best: 99.42%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.017256
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.058268
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.083582
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.031135
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.073415
#
# Test set: Average loss: 0.0380, Accuracy: 9906/10000 (99.06%) (best: 99.42%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.128332
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.056378
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.090797
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.081296
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.014806
#
# Test set: Average loss: 0.0432, Accuracy: 9914/10000 (99.14%) (best: 99.42%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.011166
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.052750
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.157926
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.014588
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.028415
#
# Test set: Average loss: 0.0583, Accuracy: 9894/10000 (98.94%) (best: 99.42%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.074657
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.022761
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.059752
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.133127
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.042429
# Best accuracy! correct images:  9955
#
# Test set: Average loss: 0.0206, Accuracy: 9955/10000 (99.55%) (best: 99.55%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.060641
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.036606
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.015808
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.017437
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.011609
#
# Test set: Average loss: 0.0375, Accuracy: 9892/10000 (98.92%) (best: 99.55%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.074182
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.031510
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.060327
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.011023
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.023070
#
# Test set: Average loss: 0.0187, Accuracy: 9953/10000 (99.53%) (best: 99.55%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#        BatchNorm2d-2           [-1, 32, 26, 26]              64
#             Conv2d-3           [-1, 48, 24, 24]          13,824
#        BatchNorm2d-4           [-1, 48, 24, 24]              96
#             Conv2d-5           [-1, 64, 22, 22]          27,648
#        BatchNorm2d-6           [-1, 64, 22, 22]             128
#             Conv2d-7           [-1, 80, 20, 20]          46,080
#        BatchNorm2d-8           [-1, 80, 20, 20]             160
#             Conv2d-9           [-1, 96, 18, 18]          69,120
#       BatchNorm2d-10           [-1, 96, 18, 18]             192
#            Conv2d-11          [-1, 112, 16, 16]          96,768
#       BatchNorm2d-12          [-1, 112, 16, 16]             224
#            Conv2d-13          [-1, 128, 14, 14]         129,024
#       BatchNorm2d-14          [-1, 128, 14, 14]             256
#            Conv2d-15          [-1, 144, 12, 12]         165,888
#       BatchNorm2d-16          [-1, 144, 12, 12]             288
#            Conv2d-17          [-1, 160, 10, 10]         207,360
#       BatchNorm2d-18          [-1, 160, 10, 10]             320
#            Conv2d-19            [-1, 176, 8, 8]         253,440
#       BatchNorm2d-20            [-1, 176, 8, 8]             352
#            Linear-21                   [-1, 10]         112,640
#       BatchNorm1d-22                   [-1, 10]              20
# ================================================================
# Total params: 1,124,180
# Trainable params: 1,124,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.74
# Params size (MB): 4.29
# Estimated Total Size (MB): 8.03
# ----------------------------------------------------------------
# Train Epoch: 0 [00000/60000 (0%)]	Loss: 2.824238
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.779175
# Train Epoch: 0 [24000/60000 (40%)]	Loss: 0.420170
# Train Epoch: 0 [36000/60000 (60%)]	Loss: 0.376783
# Train Epoch: 0 [48000/60000 (80%)]	Loss: 0.347736
# Best accuracy! correct images:  9898
#
# Test set: Average loss: 0.1150, Accuracy: 9898/10000 (98.98%) (best: 98.98%)
#
# Train Epoch: 1 [00000/60000 (0%)]	Loss: 0.222965
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.253201
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.167466
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.232546
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.107659
#
# Test set: Average loss: 0.0777, Accuracy: 9897/10000 (98.97%) (best: 98.98%)
#
# Train Epoch: 2 [00000/60000 (0%)]	Loss: 0.129310
# Train Epoch: 2 [12000/60000 (20%)]	Loss: 0.170081
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.148910
# Train Epoch: 2 [36000/60000 (60%)]	Loss: 0.124040
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.142622
#
# Test set: Average loss: 0.0641, Accuracy: 9890/10000 (98.90%) (best: 98.98%)
#
# Train Epoch: 3 [00000/60000 (0%)]	Loss: 0.167744
# Train Epoch: 3 [12000/60000 (20%)]	Loss: 0.092908
# Train Epoch: 3 [24000/60000 (40%)]	Loss: 0.068874
# Train Epoch: 3 [36000/60000 (60%)]	Loss: 0.110043
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.073822
# Best accuracy! correct images:  9931
#
# Test set: Average loss: 0.0383, Accuracy: 9931/10000 (99.31%) (best: 99.31%)
#
# Train Epoch: 4 [00000/60000 (0%)]	Loss: 0.073370
# Train Epoch: 4 [12000/60000 (20%)]	Loss: 0.078703
# Train Epoch: 4 [24000/60000 (40%)]	Loss: 0.092001
# Train Epoch: 4 [36000/60000 (60%)]	Loss: 0.107591
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.061704
#
# Test set: Average loss: 0.0472, Accuracy: 9923/10000 (99.23%) (best: 99.31%)
#
# Train Epoch: 5 [00000/60000 (0%)]	Loss: 0.044599
# Train Epoch: 5 [12000/60000 (20%)]	Loss: 0.053033
# Train Epoch: 5 [24000/60000 (40%)]	Loss: 0.072605
# Train Epoch: 5 [36000/60000 (60%)]	Loss: 0.077312
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.094481
# Best accuracy! correct images:  9942
#
# Test set: Average loss: 0.0276, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 6 [00000/60000 (0%)]	Loss: 0.127032
# Train Epoch: 6 [12000/60000 (20%)]	Loss: 0.053428
# Train Epoch: 6 [24000/60000 (40%)]	Loss: 0.097451
# Train Epoch: 6 [36000/60000 (60%)]	Loss: 0.056779
# Train Epoch: 6 [48000/60000 (80%)]	Loss: 0.035936
#
# Test set: Average loss: 0.0592, Accuracy: 9849/10000 (98.49%) (best: 99.42%)
#
# Train Epoch: 7 [00000/60000 (0%)]	Loss: 0.141862
# Train Epoch: 7 [12000/60000 (20%)]	Loss: 0.041775
# Train Epoch: 7 [24000/60000 (40%)]	Loss: 0.085265
# Train Epoch: 7 [36000/60000 (60%)]	Loss: 0.088792
# Train Epoch: 7 [48000/60000 (80%)]	Loss: 0.073846
#
# Test set: Average loss: 0.0367, Accuracy: 9923/10000 (99.23%) (best: 99.42%)
#
# Train Epoch: 8 [00000/60000 (0%)]	Loss: 0.049667
# Train Epoch: 8 [12000/60000 (20%)]	Loss: 0.029247
# Train Epoch: 8 [24000/60000 (40%)]	Loss: 0.016200
# Train Epoch: 8 [36000/60000 (60%)]	Loss: 0.084161
# Train Epoch: 8 [48000/60000 (80%)]	Loss: 0.077702
#
# Test set: Average loss: 0.0440, Accuracy: 9916/10000 (99.16%) (best: 99.42%)
#
# Train Epoch: 9 [00000/60000 (0%)]	Loss: 0.023125
# Train Epoch: 9 [12000/60000 (20%)]	Loss: 0.077371
# Train Epoch: 9 [24000/60000 (40%)]	Loss: 0.042298
# Train Epoch: 9 [36000/60000 (60%)]	Loss: 0.047565
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.030753
#
# Test set: Average loss: 0.0343, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 10 [00000/60000 (0%)]	Loss: 0.027144
# Train Epoch: 10 [12000/60000 (20%)]	Loss: 0.160406
# Train Epoch: 10 [24000/60000 (40%)]	Loss: 0.073111
# Train Epoch: 10 [36000/60000 (60%)]	Loss: 0.020369
# Train Epoch: 10 [48000/60000 (80%)]	Loss: 0.085663
#
# Test set: Average loss: 0.0474, Accuracy: 9903/10000 (99.03%) (best: 99.42%)
#
# Train Epoch: 11 [00000/60000 (0%)]	Loss: 0.090114
# Train Epoch: 11 [12000/60000 (20%)]	Loss: 0.048048
# Train Epoch: 11 [24000/60000 (40%)]	Loss: 0.028322
# Train Epoch: 11 [36000/60000 (60%)]	Loss: 0.015536
# Train Epoch: 11 [48000/60000 (80%)]	Loss: 0.060280
#
# Test set: Average loss: 0.0240, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 12 [00000/60000 (0%)]	Loss: 0.089285
# Train Epoch: 12 [12000/60000 (20%)]	Loss: 0.030523
# Train Epoch: 12 [24000/60000 (40%)]	Loss: 0.067374
# Train Epoch: 12 [36000/60000 (60%)]	Loss: 0.051214
# Train Epoch: 12 [48000/60000 (80%)]	Loss: 0.026638
#
# Test set: Average loss: 0.0308, Accuracy: 9932/10000 (99.32%) (best: 99.42%)
#
# Train Epoch: 13 [00000/60000 (0%)]	Loss: 0.032956
# Train Epoch: 13 [12000/60000 (20%)]	Loss: 0.094076
# Train Epoch: 13 [24000/60000 (40%)]	Loss: 0.039648
# Train Epoch: 13 [36000/60000 (60%)]	Loss: 0.048605
# Train Epoch: 13 [48000/60000 (80%)]	Loss: 0.021069
#
# Test set: Average loss: 0.0248, Accuracy: 9942/10000 (99.42%) (best: 99.42%)
#
# Train Epoch: 14 [00000/60000 (0%)]	Loss: 0.025521
# Train Epoch: 14 [12000/60000 (20%)]	Loss: 0.012903
# Train Epoch: 14 [24000/60000 (40%)]	Loss: 0.016284
# Train Epoch: 14 [36000/60000 (60%)]	Loss: 0.046921
# Train Epoch: 14 [48000/60000 (80%)]	Loss: 0.016356
# Best accuracy! correct images:  9949
#
# Test set: Average loss: 0.0210, Accuracy: 9949/10000 (99.49%) (best: 99.49%)

# %% [markdown]
# **TEST**

# %%
# imports ---------------------------------------------------------------------#
import sys 
import os 
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import numpy as np 
import torch 
import torch.nn as nn 
import torch.nn.functional as F  
import torch.optim as optim 
from torchvision import datasets, transforms 
from PIL import Image 

def run(p_seed=0, p_kernel_size=5, p_logdir="temp"):

    # enable GPU usage ------------------------------------------------------------#
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
    if use_cuda == False:
        print("WARNING: CPU will be used for training.")
        exit(0)

    # data loader -----------------------------------------------------------------#
    test_dataset = MnistDataset(training=False, transform=None)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False)

    # model selection -------------------------------------------------------------#
    if(p_kernel_size == 3):
        model1 = ModelM3().to(device)
    elif(p_kernel_size == 5):
        model1 = ModelM5().to(device)
    elif(p_kernel_size == 7):
        model1 = ModelM7().to(device)
   
    model1.load_state_dict(torch.load("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s/model%03d.pth"%(p_logdir,p_seed)))

    model1.eval()
    test_loss = 0
    correct = 0
    wrong_images = []
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)
            output = model1(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            wrong_images.extend(np.nonzero(~pred.eq(target.view_as(pred)).cpu().numpy())[0]+(100*batch_idx))

    np.savetxt("/content/drive/MyDrive/MnistSimpleCNN-master/logs/%s/wrong%03d.txt"%(p_logdir,p_seed), wrong_images, fmt="%d")
  
    print(len(wrong_images), wrong_images)


p_logdir = input ("Logdir: ") 
p_seed = int(input ("Seeds: ")) 
p_trials = int(input ("Trials: ")) 
p_kernel_size = int (input ("Kernel size: ")) 


for x in range (p_trials): 
  run(p_seed + x, p_kernel_size, p_logdir)
# Out:
# Logdir: modelM3_baru
# Seeds: 0
# Trials: 15
# Kernel size: 3
# 50 [321, 359, 449, 582, 882, 938, 947, 1112, 1114, 1226, 1232, 1260, 1328, 1621, 1716, 1901, 1911, 2040, 2130, 2266, 2293, 2462, 2597, 3073, 3225, 3266, 3762, 3976, 4018, 4699, 4736, 4740, 4761, 5745, 5955, 6554, 6576, 6625, 6651, 8275, 8279, 8316, 8408, 8527, 9009, 9024, 9505, 9729, 9754, 9850]
# 48 [36, 193, 359, 447, 582, 625, 1226, 1232, 1260, 1299, 1393, 1621, 1737, 1901, 1903, 1911, 2035, 2040, 2130, 2189, 2293, 2454, 2462, 2597, 2959, 3073, 3534, 3558, 3762, 4443, 4761, 4860, 5654, 5937, 6576, 6599, 6625, 7216, 8275, 8316, 8325, 8408, 8527, 9009, 9505, 9729, 9749, 9754]
# 50 [193, 359, 445, 593, 625, 659, 882, 1232, 1299, 1508, 1737, 1901, 2035, 2040, 2118, 2130, 2189, 2293, 2406, 2454, 2462, 2597, 3005, 3030, 3225, 3384, 3422, 3534, 3762, 4443, 4547, 4761, 5654, 5937, 6558, 6576, 6599, 6625, 8316, 8325, 8387, 8408, 8527, 9505, 9530, 9664, 9672, 9679, 9698, 9729]
# 41 [193, 359, 582, 625, 646, 1232, 1247, 1260, 1393, 1508, 1716, 1901, 2035, 2040, 2130, 2189, 2293, 2454, 2462, 2597, 3225, 3422, 3534, 3762, 3821, 4284, 4761, 5654, 5745, 5937, 6576, 6599, 6625, 8275, 8316, 8408, 8527, 9009, 9024, 9505, 9729]
# 45 [193, 247, 321, 359, 449, 582, 646, 938, 1112, 1232, 1247, 1260, 1299, 1508, 1716, 1901, 1911, 2040, 2098, 2130, 2293, 2462, 2488, 3005, 3422, 3558, 3762, 4443, 4740, 4761, 5955, 6554, 6576, 6625, 6651, 8275, 8279, 8408, 8527, 9664, 9729, 9749, 9754, 9811, 9839]
# 51 [115, 321, 445, 447, 582, 625, 659, 938, 947, 1299, 1393, 1737, 1901, 2035, 2040, 2118, 2130, 2447, 2454, 2462, 2597, 2654, 2771, 3030, 3365, 3422, 3475, 4176, 4201, 4497, 4699, 4761, 4860, 5937, 6554, 6555, 6576, 6625, 8061, 8275, 8279, 8408, 8527, 9664, 9669, 9679, 9698, 9729, 9754, 9792, 9888]
# 53 [359, 445, 447, 582, 625, 965, 1226, 1232, 1260, 1299, 1393, 1737, 1901, 2035, 2040, 2118, 2130, 2293, 2338, 2454, 2597, 2654, 3030, 3073, 3225, 3365, 3422, 3534, 3762, 3821, 4201, 4699, 4761, 4823, 4860, 5937, 6554, 6558, 6576, 6597, 6599, 6625, 7216, 8279, 8408, 8527, 9009, 9015, 9505, 9679, 9698, 9729, 9888]
# 45 [8, 447, 449, 582, 646, 938, 1232, 1260, 1299, 1621, 1716, 1737, 1901, 1911, 2035, 2040, 2130, 2293, 2462, 2597, 2654, 3225, 3266, 3762, 3821, 4443, 4699, 4740, 4761, 6554, 6574, 6576, 6599, 6625, 6651, 8275, 8316, 8408, 8527, 9009, 9505, 9669, 9729, 9749, 9754]
# 47 [321, 447, 449, 582, 659, 938, 947, 1039, 1226, 1232, 1260, 1299, 1393, 1737, 1901, 2040, 2130, 2293, 2326, 2338, 2447, 2462, 2771, 3030, 3225, 3422, 3534, 3762, 4443, 4699, 4740, 4860, 5937, 6554, 6558, 6569, 6576, 6597, 6625, 8275, 8527, 9009, 9669, 9679, 9698, 9729, 9754]
# 48 [321, 412, 447, 582, 625, 674, 947, 1232, 1299, 1364, 1393, 1737, 1878, 1901, 2035, 2118, 2130, 2135, 2148, 2447, 2454, 2462, 2597, 2654, 2771, 3030, 3073, 3225, 3365, 3422, 3762, 4201, 4699, 4860, 5937, 6554, 6576, 6625, 7441, 8061, 8279, 8316, 8408, 8527, 9009, 9505, 9698, 9729]
# 56 [124, 321, 358, 359, 449, 582, 625, 659, 726, 938, 947, 1039, 1232, 1260, 1438, 1621, 1716, 1901, 2040, 2130, 2293, 2454, 2462, 2488, 2523, 2597, 2654, 3225, 3266, 3796, 4018, 4053, 4065, 4443, 4504, 4551, 4699, 4740, 4761, 4860, 6554, 6555, 6576, 6599, 6625, 6651, 6755, 7216, 7565, 8279, 8408, 8527, 9679, 9698, 9729, 9839]
# 43 [359, 449, 582, 625, 646, 947, 1114, 1226, 1232, 1260, 1299, 1393, 1621, 1737, 1901, 2040, 2130, 2293, 2462, 2488, 2597, 2654, 3073, 3225, 3422, 3534, 3558, 3762, 3808, 4740, 4761, 5654, 5937, 6558, 6576, 6625, 8279, 8408, 8527, 9009, 9015, 9505, 9729]
# 46 [193, 447, 449, 582, 625, 938, 1112, 1226, 1232, 1299, 1393, 1403, 1621, 1737, 1901, 2040, 2130, 2293, 2326, 2447, 2454, 2597, 2771, 3073, 3225, 3266, 4201, 4740, 4860, 5654, 6554, 6576, 6599, 6625, 6651, 8316, 8387, 8408, 8527, 9009, 9024, 9505, 9669, 9729, 9792, 9850]
# 46 [321, 359, 449, 582, 625, 938, 947, 1114, 1226, 1232, 1260, 1299, 1621, 1681, 1901, 1940, 2040, 2130, 2293, 2414, 2462, 2534, 2597, 3108, 3225, 3475, 3762, 4018, 4176, 4437, 4443, 4740, 4761, 5955, 6569, 6576, 6625, 7216, 8275, 8279, 8316, 8527, 9009, 9024, 9729, 9754]
# 50 [321, 359, 582, 625, 882, 947, 1226, 1232, 1260, 1299, 1393, 1508, 1621, 1901, 2035, 2040, 2130, 2135, 2293, 2454, 2597, 2654, 2760, 3225, 3365, 3422, 3762, 3821, 3850, 4176, 4284, 4443, 4699, 4740, 4761, 4823, 5937, 6554, 6569, 6576, 6599, 6625, 8275, 8279, 8408, 9009, 9698, 9729, 9749, 9754]

# %% [markdown]
# *Pada bagian test sudah dilakukan 20x tiral dan dalam setiap trialnya dilakukan 15 epoch. Dengan menggunakan logdir modelM3_baru sebagai folder untuk menyimpan hasil training. Maka didapatkanlah beberapa hasil dengan nilai akurat yang sangat tinggi. *

# %% [markdown]
# **Homo Ensemble**

# %%
import numpy as np 

cnt = 1
best = 10000
curr = 10000

p_kernel_size = int (input ("Kernel size: ")) 
KERNEL_SIZE = p_kernel_size 

for i in range(3):
    for j in range(i+1,3):
        for k in range(j+1,3):
            w1 = np.loadtxt("/content/drive/MyDrive/MnistSimpleCNN-master/logs/modelM%d_baru/wrong%003d.txt"%(KERNEL_SIZE, i)).astype(np.int)
            w2 = np.loadtxt("/content/drive/MyDrive/MnistSimpleCNN-master/logs/modelM%d_baru/wrong%003d.txt"%(KERNEL_SIZE, j)).astype(np.int)
            w3 = np.loadtxt("/content/drive/MyDrive/MnistSimpleCNN-master/logs/modelM%d_baru/wrong%003d.txt"%(KERNEL_SIZE, k)).astype(np.int)

            board = np.zeros((10000))
            board[w1] += 1
            board[w2] += 1
            board[w3] += 1
            board = board // 2
            curr = np.sum(board)
            if curr < best:
                best = curr
            print("%4d %4d %4d %4d %4d %4d"%(cnt, len(w1), len(w2), len(w3), curr, best))
            cnt += 1
# Out:
# Kernel size: 3
#    1   50   48   50   41   41
